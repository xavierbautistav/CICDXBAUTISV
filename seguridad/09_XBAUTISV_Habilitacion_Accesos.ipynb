-- %%
GRANT USE SCHEMA ON SCHEMA XBAUTISV_PRD.GOLD TO `GP_ANALISTA_DATOS`;
GRANT USE SCHEMA ON SCHEMA XBAUTISV_PRD.SILVER TO `GP_INGENIERO_DATOS`;
GRANT USE SCHEMA ON SCHEMA XBAUTISV_PRD.BRONZE TO `GP_INGENIERO_DATOS`;
GRANT USE SCHEMA ON SCHEMA XBAUTISV_PRD.GOLD TO `GP_INGENIERO_DATOS`;

GRANT CREATE ON SCHEMA XBAUTISV_PRD.SILVER TO `GP_INGENIERO_DATOS`;
GRANT CREATE ON SCHEMA XBAUTISV_PRD.BRONZE TO `GP_INGENIERO_DATOS`;
GRANT CREATE ON SCHEMA XBAUTISV_PRD.GOLD TO `GP_INGENIERO_DATOS`;

GRANT SELECT ON SCHEMA XBAUTISV_PRD.GOLD TO `GP_ANALISTA_DATOS`;
GRANT SELECT ON SCHEMA XBAUTISV_PRD.BRONZE TO `GP_INGENIERO_DATOS`;
GRANT SELECT ON SCHEMA XBAUTISV_PRD.SILVER TO `GP_INGENIERO_DATOS`;
GRANT SELECT ON SCHEMA XBAUTISV_PRD.GOLD TO `GP_INGENIERO_DATOS`;

GRANT READ FILES ON EXTERNAL LOCATION `exlt-raw-prd` TO `GP_INGENIERO_DATOS`;
GRANT READ FILES ON EXTERNAL LOCATION `exlt-bronze-prd` TO `GP_INGENIERO_DATOS`;
GRANT READ FILES ON EXTERNAL LOCATION `exlt-silver-prd` TO `GP_INGENIERO_DATOS`;
GRANT READ FILES ON EXTERNAL LOCATION `exlt-golden-prd` TO `GP_INGENIERO_DATOS`;

-- %%
SHOW GRANTS ON SCHEMA XBAUTISV_PRD.BRONZE;

-- %%
SHOW GRANTS ON TABLE
