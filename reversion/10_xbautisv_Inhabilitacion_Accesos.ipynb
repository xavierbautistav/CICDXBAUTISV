-- %%
REVOKE USE SCHEMA ON SCHEMA XBAUTISV_PRD.GOLD FROM `GP_ANALISTA_DATOS`;

REVOKE USE SCHEMA ON SCHEMA XBAUTISV_PRD.SILVER FROM `GP_INGENIERO_DATOS`;
REVOKE USE SCHEMA ON SCHEMA XBAUTISV_PRD.BRONZE FROM `GP_INGENIERO_DATOS`;
REVOKE USE SCHEMA ON SCHEMA XBAUTISV_PRD.GOLD FROM `GP_INGENIERO_DATOS`;

REVOKE CREATE ON SCHEMA XBAUTISV_PRD.SILVER FROM `GP_INGENIERO_DATOS`;
REVOKE CREATE ON SCHEMA XBAUTISV_PRD.BRONZE FROM `GP_INGENIERO_DATOS`;
REVOKE CREATE ON SCHEMA XBAUTISV_PRD.GOLD FROM `GP_INGENIERO_DATOS`;

REVOKE SELECT ON SCHEMA XBAUTISV_PRD.GOLD FROM `GP_ANALISTA_DATOS`;
REVOKE SELECT ON SCHEMA XBAUTISV_PRD.BRONZE FROM `GP_INGENIERO_DATOS`;
REVOKE SELECT ON SCHEMA XBAUTISV_PRD.SILVER FROM `GP_INGENIERO_DATOS`;
REVOKE SELECT ON SCHEMA XBAUTISV_PRD.GOLD FROM `GP_INGENIERO_DATOS`;

REVOKE READ FILES ON EXTERNAL LOCATION `exlt-raw-prd` FROM `GP_INGENIERO_DATOS`;
REVOKE READ FILES ON EXTERNAL LOCATION `exlt-bronze-prd` FROM `GP_INGENIERO_DATOS`;
REVOKE READ FILES ON EXTERNAL LOCATION `exlt-silver-prd` FROM `GP_INGENIERO_DATOS`;
REVOKE READ FILES ON EXTERNAL LOCATION `exlt-golden-prd` FROM `GP_INGENIERO_DATOS`;

DROP GROUP GP_INGENIERO_DATOS;
DROP GROUP GP_ANALISTA_DATOS;
